# %% [markdown]
# ## Deploy HuggingFace models with ezsmdeploy
#
# Welcome to EZSMdeploy! You can use EZSMdeploy to deploy many Machine Learning models on AWS.
#
# In this demo notebook, we demonstrate how to use the EZSMdeploy for deploying Foundation Models as an endpoint and use them for various NLP tasks. The Foundation models perform Text2Text Generation. It takes a prompting text as an input, and returns the text generated by the model according to the prompt.
#
# Here, we show how to deploy the state-of-the-art pre-trained models from Hugging Face for Text2Text Generation in the following tasks. You can directly use these models for many NLP tasks, without fine-tuning the model.
#
# - Text summarization
#
# - Common sense reasoning / natural language inference
#
# - Question and answering
#
# - Sentence / sentiment classification
#
# - Translation
#
# - Pronoun resolution

# %%
# %pip uninstall -y ezsmdeploy --quiet
# !pip install --upgrade pip
# %pip install ezsmdeploy==2.0.5
# Out:
# WARNING: Skipping ezsmdeploy as it is not installed.
# Note: you may need to restart the kernel to use updated packages.
# Looking in indexes: https://pypi.org/simple, https://pip.repos.neuron.amazonaws.com
# Collecting ezsmdeploy==2.0.5
#   Downloading ezsmdeploy-2.0.5-py3-none-any.whl (31 kB)
# Collecting sagemaker-studio-image-build==0.5.0
#   Downloading sagemaker_studio_image_build-0.5.0.tar.gz (11 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: boto3>=1.14.12 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from ezsmdeploy==2.0.5) (1.28.62)
# Collecting yaspin==0.16.0
#   Downloading yaspin-0.16.0-py2.py3-none-any.whl (18 kB)
# Collecting sagemaker==2.196.0
#   Downloading sagemaker-2.196.0.tar.gz (916 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 916.9/916.9 kB 24.4 MB/s eta 0:00:0000:01
#   Preparing metadata (setup.py) ... done
# Collecting shortuuid==1.0.1
#   Downloading shortuuid-1.0.1-py3-none-any.whl (7.5 kB)
# Requirement already satisfied: attrs<24,>=23.1.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from sagemaker==2.196.0->ezsmdeploy==2.0.5) (23.1.0)
# Requirement already satisfied: cloudpickle==2.2.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from sagemaker==2.196.0->ezsmdeploy==2.0.5) (2.2.1)
# Requirement already satisfied: google-pasta in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from sagemaker==2.196.0->ezsmdeploy==2.0.5) (0.2.0)
# Requirement already satisfied: numpy<2.0,>=1.9.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from sagemaker==2.196.0->ezsmdeploy==2.0.5) (1.22.3)
# Requirement already satisfied: protobuf<5.0,>=3.12 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from sagemaker==2.196.0->ezsmdeploy==2.0.5) (3.20.3)
# Requirement already satisfied: smdebug_rulesconfig==1.0.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from sagemaker==2.196.0->ezsmdeploy==2.0.5) (1.0.1)
# Requirement already satisfied: importlib-metadata<7.0,>=1.4.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from sagemaker==2.196.0->ezsmdeploy==2.0.5) (4.13.0)
# Requirement already satisfied: packaging>=20.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from sagemaker==2.196.0->ezsmdeploy==2.0.5) (21.3)
# Requirement already satisfied: pandas in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from sagemaker==2.196.0->ezsmdeploy==2.0.5) (1.5.2)
# Requirement already satisfied: pathos in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from sagemaker==2.196.0->ezsmdeploy==2.0.5) (0.3.0)
# Requirement already satisfied: schema in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from sagemaker==2.196.0->ezsmdeploy==2.0.5) (0.7.5)
# Requirement already satisfied: PyYAML~=6.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from sagemaker==2.196.0->ezsmdeploy==2.0.5) (6.0)
# Requirement already satisfied: jsonschema in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from sagemaker==2.196.0->ezsmdeploy==2.0.5) (3.2.0)
# Requirement already satisfied: platformdirs in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from sagemaker==2.196.0->ezsmdeploy==2.0.5) (2.6.2)
# Requirement already satisfied: tblib==1.7.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from sagemaker==2.196.0->ezsmdeploy==2.0.5) (1.7.0)
# Requirement already satisfied: botocore<1.32.0,>=1.31.62 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from boto3>=1.14.12->ezsmdeploy==2.0.5) (1.31.62)
# Requirement already satisfied: s3transfer<0.8.0,>=0.7.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from boto3>=1.14.12->ezsmdeploy==2.0.5) (0.7.0)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from boto3>=1.14.12->ezsmdeploy==2.0.5) (1.0.1)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from botocore<1.32.0,>=1.31.62->boto3>=1.14.12->ezsmdeploy==2.0.5) (2.8.2)
# Requirement already satisfied: urllib3<2.1,>=1.25.4 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from botocore<1.32.0,>=1.31.62->boto3>=1.14.12->ezsmdeploy==2.0.5) (1.26.8)
# Requirement already satisfied: zipp>=0.5 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from importlib-metadata<7.0,>=1.4.0->sagemaker==2.196.0->ezsmdeploy==2.0.5) (3.11.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from packaging>=20.0->sagemaker==2.196.0->ezsmdeploy==2.0.5) (3.0.9)
# Requirement already satisfied: six in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from google-pasta->sagemaker==2.196.0->ezsmdeploy==2.0.5) (1.16.0)
# Requirement already satisfied: setuptools in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from jsonschema->sagemaker==2.196.0->ezsmdeploy==2.0.5) (65.6.3)
# Requirement already satisfied: pyrsistent>=0.14.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from jsonschema->sagemaker==2.196.0->ezsmdeploy==2.0.5) (0.19.3)
# Requirement already satisfied: pytz>=2020.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from pandas->sagemaker==2.196.0->ezsmdeploy==2.0.5) (2022.7)
# Requirement already satisfied: ppft>=1.7.6.6 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from pathos->sagemaker==2.196.0->ezsmdeploy==2.0.5) (1.7.6.6)
# Requirement already satisfied: dill>=0.3.6 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from pathos->sagemaker==2.196.0->ezsmdeploy==2.0.5) (0.3.6)
# Requirement already satisfied: multiprocess>=0.70.14 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from pathos->sagemaker==2.196.0->ezsmdeploy==2.0.5) (0.70.14)
# Requirement already satisfied: pox>=0.3.2 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from pathos->sagemaker==2.196.0->ezsmdeploy==2.0.5) (0.3.2)
# Requirement already satisfied: contextlib2>=0.5.5 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from schema->sagemaker==2.196.0->ezsmdeploy==2.0.5) (21.6.0)
# Building wheels for collected packages: sagemaker, sagemaker-studio-image-build
#   Building wheel for sagemaker (setup.py) ... done
#   Created wheel for sagemaker: filename=sagemaker-2.196.0-py2.py3-none-any.whl size=1223208 sha256=49daa5f7f3055c50a1331504cc1a0895cfbd38abbccc73ea6a1b244808196b0f
#   Stored in directory: /home/ec2-user/.cache/pip/wheels/bc/d1/a2/c0e89b311afc680a365ccd0baedfbd9d31f339d37b6460367f
#   Building wheel for sagemaker-studio-image-build (setup.py) ... done
#   Created wheel for sagemaker-studio-image-build: filename=sagemaker_studio_image_build-0.5.0-py3-none-any.whl size=11236 sha256=7f775f6717998d3120dd45f9b41dc92ebff4253c67e03f5305b1fc7051fc8027
#   Stored in directory: /home/ec2-user/.cache/pip/wheels/0f/9c/26/b3c35ed5d7f58debf2a5111b3aa6c400292a3adcaef810a147
# Successfully built sagemaker sagemaker-studio-image-build
# Installing collected packages: yaspin, shortuuid, sagemaker, sagemaker-studio-image-build, ezsmdeploy
#   Attempting uninstall: sagemaker
#     Found existing installation: sagemaker 2.191.0
#     Uninstalling sagemaker-2.191.0:
#       Successfully uninstalled sagemaker-2.191.0
# Successfully installed ezsmdeploy-2.0.5 sagemaker-2.196.0 sagemaker-studio-image-build-0.5.0 shortuuid-1.0.1 yaspin-0.16.0
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ### Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## Testing foundation model

# %%
import sagemaker
sagemaker.__version__
# Out:
# sagemaker.config INFO - Not applying SDK defaults from location: /etc/xdg/sagemaker/config.yaml
# sagemaker.config INFO - Not applying SDK defaults from location: /home/ec2-user/.config/sagemaker/config.yaml
# '2.196.0'

# %%
# !pip show ezsmdeploy
# Out:
# Name: ezsmdeploy
# Version: 2.0.5
# Summary: SageMaker custom deployments made easy
# Home-page: https://pypi.python.org/pypi/ezsmdeploy
# Author: Shreyas Subramanian
# Author-email: subshrey@amazon.com
# License: MIT
# Location: /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages
# Requires: boto3, sagemaker, sagemaker-studio-image-build, shortuuid, yaspin
# Required-by:

# %%
import ezsmdeploy

# %%
ezonsm = ezsmdeploy.Deploy(model = "tiiuae/falcon-7b",
                           huggingface_model=True,
                           foundation_model=True,
                           instance_type='ml.g5.8xlarge'
                           )
# Out:
# sagemaker.config INFO - Not applying SDK defaults from location: /etc/xdg/sagemaker/config.yaml
# sagemaker.config INFO - Not applying SDK defaults from location: /home/ec2-user/.config/sagemaker/config.yaml
# ∙●∙ sagemaker.config INFO - Not applying SDK defaults from location: /etc/xdg/sagemaker/config.yaml
# sagemaker.config INFO - Not applying SDK defaults from location: /home/ec2-user/.config/sagemaker/config.yaml
# ∙∙● sagemaker.config INFO - Not applying SDK defaults from location: /etc/xdg/sagemaker/config.yaml
# sagemaker.config INFO - Not applying SDK defaults from location: /home/ec2-user/.config/sagemaker/config.yaml
# sagemaker.config INFO - Not applying SDK defaults from location: /etc/xdg/sagemaker/config.yaml
# sagemaker.config INFO - Not applying SDK defaults from location: /home/ec2-user/.config/sagemaker/config.yaml
# sagemaker.config INFO - Not applying SDK defaults from location: /etc/xdg/sagemaker/config.yaml
# sagemaker.config INFO - Not applying SDK defaults from location: /home/ec2-user/.config/sagemaker/config.yaml
# 0:00:00.503767 | created model(s). Now deploying on ml.g5.8xlarge
# 0:06:33.216746 | deployed model
# 0:06:33.216848 | Done! ✔

# %%
ezonsm.predictor.predict({"inputs":"Paris is the capital of "})
# Out:
# [{'generated_text': 'Paris is the capital of “France” and is the most populous city in France. It is also the most visited city'}]

# %%
ezonsm.predictor.delete_endpoint()
