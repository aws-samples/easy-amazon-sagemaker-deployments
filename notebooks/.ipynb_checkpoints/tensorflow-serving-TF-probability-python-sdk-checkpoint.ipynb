# %%
# !pip install --upgrade tensorflow tensorflow-probability h5py ezsmdeploy==1.1.4 --quiet

# %%
import numpy as np

import tensorflow.compat.v2 as tf
tf.enable_v2_behavior()

import tensorflow_probability as tfp

# %matplotlib inline

tfd = tfp.distributions

# %% [markdown]
# ### Create Sample Data

# %%
w0 = 0.125
b0 = 5.
x_range = [-20, 60]

def load_dataset(n=150, n_tst=150):
  np.random.seed(43)
  def s(x):
    g = (x - x_range[0]) / (x_range[1] - x_range[0])
    return 3 * (0.25 + g**2.)
  x = (x_range[1] - x_range[0]) * np.random.rand(n) + x_range[0]
  eps = np.random.randn(n) * s(x)
  y = (w0 * x * (1. + np.sin(x)) + b0) + eps
  x = x[..., np.newaxis]
  x_tst = np.linspace(*x_range, num=n_tst).astype(np.float32)
  x_tst = x_tst[..., np.newaxis]
  return y, x, x_tst

y, x, x_tst = load_dataset()

# %% [markdown]
# ### Build model

# %%
# Build model.
negloglik = lambda y, rv_y: -rv_y.log_prob(y)
model = tf.keras.Sequential([
  tf.keras.layers.Dense(1 + 1),
  tfp.layers.DistributionLambda(
      lambda t: tfd.Normal(loc=t[..., :1],
                           scale=1e-3 + tf.math.softplus(0.05 * t[...,1:]))),
])

# Do inference.
model.compile(optimizer=tf.optimizers.Adam(learning_rate=0.01), loss=negloglik)
model.fit(x, y, epochs=1000, verbose=False);

# Profit.
[print(np.squeeze(w.numpy())) for w in model.weights];
yhat = model(x_tst)
assert isinstance(yhat, tfd.Distribution)
# Out:
# [0.12282385 0.96513146]
# [5.205943 7.004342]

# %%
model(x_tst)
# Out:
# <tfp.distributions.Normal 'sequential_distribution_lambda_Normal' batch_shape=[150, 1] event_shape=[] dtype=float32>

# %%
model.predict(x_tst) # <--- this is what happens internally. It returns a tensor instead of a distribution we can sample from
# Out:
# array([[ 2.3980758],
#        [ 2.585518 ],
#        [ 2.1993608],
#        [ 3.3034415],
#        [ 4.2840652],
#        [ 3.3239174],
#        [ 4.409056 ],
#        [ 3.8066037],
#        [ 2.5256186],
#        [ 2.765533 ],
#        [ 3.600575 ],
#        [ 3.515073 ],
#        [ 3.7046757],
#        [ 3.6306553],
#        [ 3.2321055],
#        [ 4.1575603],
#        [ 4.0326014],
#        [ 3.7785063],
#        [ 4.3272724],
#        [ 4.806672 ],
#        [ 3.0966952],
#        [ 2.9335876],
#        [ 4.903344 ],
#        [ 4.9527016],
#        [ 5.3946457],
#        [ 5.4594507],
#        [ 4.637113 ],
#        [ 4.085116 ],
#        [ 4.1591053],
#        [ 5.2609854],
#        [ 4.457866 ],
#        [ 5.5775747],
#        [ 4.64046  ],
#        [ 5.479892 ],
#        [ 5.883362 ],
#        [ 5.2331967],
#        [ 5.2612853],
#        [ 5.83494  ],
#        [ 5.3080373],
#        [ 3.4654753],
#        [ 4.595876 ],
#        [ 5.613019 ],
#        [ 7.1641006],
#        [ 5.411243 ],
#        [ 4.4108014],
#        [ 4.4137125],
#        [ 4.3924646],
#        [ 6.575941 ],
#        [ 4.9020452],
#        [ 5.752693 ],
#        [ 5.75957  ],
#        [ 6.7561717],
#        [ 6.735872 ],
#        [ 7.328601 ],
#        [ 6.1419034],
#        [ 7.8903475],
#        [ 6.3336277],
#        [ 8.029983 ],
#        [ 5.8115954],
#        [ 9.221244 ],
#        [ 5.434181 ],
#        [ 5.416404 ],
#        [ 6.949654 ],
#        [ 7.5835133],
#        [ 7.047024 ],
#        [ 6.163509 ],
#        [ 9.184259 ],
#        [ 7.2144804],
#        [ 8.676065 ],
#        [ 6.328677 ],
#        [ 8.101362 ],
#        [ 6.512381 ],
#        [ 7.934642 ],
#        [ 7.144793 ],
#        [ 4.638726 ],
#        [ 5.223215 ],
#        [ 8.464865 ],
#        [ 7.552706 ],
#        [ 7.3912673],
#        [ 8.999755 ],
#        [ 8.240487 ],
#        [ 5.370043 ],
#        [ 5.718917 ],
#        [10.609743 ],
#        [ 9.844796 ],
#        [ 7.1364436],
#        [ 7.949896 ],
#        [10.435962 ],
#        [ 6.6324677],
#        [10.832504 ],
#        [ 7.19478  ],
#        [ 8.02826  ],
#        [ 8.983743 ],
#        [ 6.6742096],
#        [ 8.514823 ],
#        [ 9.011027 ],
#        [11.32958  ],
#        [ 8.490411 ],
#        [10.919889 ],
#        [ 7.4841   ],
#        [ 8.995726 ],
#        [ 6.221328 ],
#        [ 9.262134 ],
#        [ 4.919659 ],
#        [ 9.180258 ],
#        [ 6.9361362],
#        [12.201083 ],
#        [13.005651 ],
#        [13.56366  ],
#        [ 4.423607 ],
#        [13.67661  ],
#        [13.829769 ],
#        [ 6.6347733],
#        [10.86056  ],
#        [ 7.5981827],
#        [ 7.527543 ],
#        [14.481749 ],
#        [12.079195 ],
#        [11.835815 ],
#        [12.455848 ],
#        [ 9.456992 ],
#        [ 9.059851 ],
#        [11.937801 ],
#        [10.108318 ],
#        [16.862328 ],
#        [12.807475 ],
#        [10.143425 ],
#        [ 8.552404 ],
#        [11.604684 ],
#        [12.743559 ],
#        [11.394493 ],
#        [16.6679   ],
#        [12.6356325],
#        [12.761792 ],
#        [13.932957 ],
#        [12.780765 ],
#        [10.716329 ],
#        [ 7.861717 ],
#        [13.517168 ],
#        [10.692409 ],
#        [ 8.0484085],
#        [12.292107 ],
#        [17.032558 ],
#        [ 7.1869125],
#        [16.75444  ],
#        [ 9.894072 ],
#        [11.60792  ],
#        [18.098598 ],
#        [ 9.935095 ],
#        [15.545597 ]], dtype=float32)

# %%
# model.save('model1.h5')

# %% [markdown]
# _This method of saving has some problems..._

# %%
import h5py

# %%
# !rm -r models
# !mkdir models

# %%
model_name = 'reg1'
file = h5py.File('{}.h5'.format(model_name), 'w')
weight = model.get_weights()
for i in range(len(weight)):
    file.create_dataset('weight' + str(i), data=weight[i])
file.close()

# %%
negloglik = lambda y, rv_y: -rv_y.log_prob(y)
newmodel = tf.keras.Sequential([
  tf.keras.layers.Dense(1 + 1),
  tfp.layers.DistributionLambda(
      lambda t: tfd.Normal(loc=t[..., :1],
                           scale=1e-3 + tf.math.softplus(0.05 * t[...,1:]))),
])

# %%
x_tst.shape
# Out:
# (150, 1)

# %% [markdown]
# ### Reload model to see if it is saved correctly

# %%
file = h5py.File('{}.h5'.format(model_name), 'r')
weight = []
for i in range(len(file.keys())):
   weight.append(file['weight' + str(i)][:])

newmodel.build(input_shape = (150,1))
newmodel.set_weights(weight)

# %%
y_tst = newmodel(x_tst)

# %%
y_tst.__dict__
# Out:
# {'_parameters': <function tensorflow_probability.python.distributions.distribution._DistributionMeta.__new__.<locals>.wrapped_init.<locals>.<lambda>()>,
#  '_loc': <tf.Tensor: shape=(150, 1), dtype=float32, numpy=
#  array([[ 2.7494662],
#         [ 2.8154118],
#         [ 2.8813574],
#         [ 2.9473033],
#         [ 3.013249 ],
#         [ 3.0791948],
#         [ 3.1451402],
#         [ 3.2110858],
#         [ 3.2770317],
#         [ 3.3429773],
#         [ 3.4089231],
#         [ 3.4748688],
#         [ 3.5408144],
#         [ 3.60676  ],
#         [ 3.672706 ],
#         [ 3.7386513],
#         [ 3.8045971],
#         [ 3.870543 ],
#         [ 3.9364886],
#         [ 4.0024343],
#         [ 4.06838  ],
#         [ 4.1343255],
#         [ 4.200271 ],
#         [ 4.266217 ],
#         [ 4.332163 ],
#         [ 4.3981085],
#         [ 4.464054 ],
#         [ 4.5299997],
#         [ 4.5959454],
#         [ 4.661891 ],
#         [ 4.7278366],
#         [ 4.7937827],
#         [ 4.8597283],
#         [ 4.925674 ],
#         [ 4.9916196],
#         [ 5.057565 ],
#         [ 5.123511 ],
#         [ 5.1894565],
#         [ 5.2554026],
#         [ 5.321348 ],
#         [ 5.387294 ],
#         [ 5.4532394],
#         [ 5.519185 ],
#         [ 5.5851307],
#         [ 5.6510763],
#         [ 5.717022 ],
#         [ 5.782968 ],
#         [ 5.8489137],
#         [ 5.9148593],
#         [ 5.980805 ],
#         [ 6.0467505],
#         [ 6.112696 ],
#         [ 6.1786423],
#         [ 6.244588 ],
#         [ 6.3105335],
#         [ 6.376479 ],
#         [ 6.442425 ],
#         [ 6.5083704],
#         [ 6.574316 ],
#         [ 6.6402617],
#         [ 6.7062078],
#         [ 6.7721534],
#         [ 6.838099 ],
#         [ 6.9040446],
#         [ 6.9699903],
#         [ 7.0359364],
#         [ 7.1018815],
#         [ 7.1678276],
#         [ 7.233773 ],
#         [ 7.299719 ],
#         [ 7.3656645],
#         [ 7.43161  ],
#         [ 7.4975557],
#         [ 7.5635014],
#         [ 7.6294475],
#         [ 7.6953926],
#         [ 7.761338 ],
#         [ 7.8272843],
#         [ 7.89323  ],
#         [ 7.9591756],
#         [ 8.025122 ],
#         [ 8.091067 ],
#         [ 8.157013 ],
#         [ 8.222959 ],
#         [ 8.288904 ],
#         [ 8.35485  ],
#         [ 8.420795 ],
#         [ 8.486741 ],
#         [ 8.552687 ],
#         [ 8.618632 ],
#         [ 8.684578 ],
#         [ 8.7505245],
#         [ 8.816469 ],
#         [ 8.882416 ],
#         [ 8.948361 ],
#         [ 9.014307 ],
#         [ 9.080253 ],
#         [ 9.146198 ],
#         [ 9.212144 ],
#         [ 9.27809  ],
#         [ 9.344035 ],
#         [ 9.409981 ],
#         [ 9.475927 ],
#         [ 9.541872 ],
#         [ 9.607818 ],
#         [ 9.673763 ],
#         [ 9.73971  ],
#         [ 9.805655 ],
#         [ 9.871601 ],
#         [ 9.937547 ],
#         [10.003492 ],
#         [10.069438 ],
#         [10.135384 ],
#         [10.201329 ],
#         [10.267275 ],
#         [10.3332205],
#         [10.399166 ],
#         [10.465112 ],
#         [10.531057 ],
#         [10.597003 ],
#         [10.662949 ],
#         [10.728895 ],
#         [10.79484  ],
#         [10.860786 ],
#         [10.926732 ],
#         [10.992678 ],
#         [11.058623 ],
#         [11.124569 ],
#         [11.190515 ],
#         [11.25646  ],
#         [11.322406 ],
#         [11.388351 ],
#         [11.454297 ],
#         [11.520243 ],
#         [11.586189 ],
#         [11.652134 ],
#         [11.7180805],
#         [11.784026 ],
#         [11.849972 ],
#         [11.915916 ],
#         [11.981863 ],
#         [12.047808 ],
#         [12.113754 ],
#         [12.1797   ],
#         [12.2456455],
#         [12.311591 ],
#         [12.377537 ],
#         [12.443483 ],
#         [12.509428 ],
#         [12.575375 ]], dtype=float32)>,
#  '_scale': <tf.Tensor: shape=(150, 1), dtype=float32, numpy=
#  array([[0.4332285 ],
#         [0.4423979 ],
#         [0.45172122],
#         [0.46119985],
#         [0.47083476],
#         [0.4806269 ],
#         [0.49057737],
#         [0.5006872 ],
#         [0.5109571 ],
#         [0.52138805],
#         [0.53198093],
#         [0.5427364 ],
#         [0.5536552 ],
#         [0.5647379 ],
#         [0.5759854 ],
#         [0.58739793],
#         [0.5989762 ],
#         [0.6107207 ],
#         [0.62263167],
#         [0.6347096 ],
#         [0.64695466],
#         [0.65936714],
#         [0.67194724],
#         [0.6846951 ],
#         [0.6976108 ],
#         [0.71069425],
#         [0.7239456 ],
#         [0.73736453],
#         [0.750951  ],
#         [0.76470476],
#         [0.7786255 ],
#         [0.792713  ],
#         [0.80696696],
#         [0.82138675],
#         [0.8359719 ],
#         [0.8507221 ],
#         [0.86563647],
#         [0.88071454],
#         [0.89595544],
#         [0.9113587 ],
#         [0.9269233 ],
#         [0.94264865],
#         [0.9585336 ],
#         [0.97457737],
#         [0.9907788 ],
#         [1.0071372 ],
#         [1.0236511 ],
#         [1.0403197 ],
#         [1.0571417 ],
#         [1.0741159 ],
#         [1.0912412 ],
#         [1.1085163 ],
#         [1.12594   ],
#         [1.1435108 ],
#         [1.1612276 ],
#         [1.1790886 ],
#         [1.1970928 ],
#         [1.2152386 ],
#         [1.2335246 ],
#         [1.2519491 ],
#         [1.2705108 ],
#         [1.289208  ],
#         [1.3080395 ],
#         [1.3270035 ],
#         [1.3460983 ],
#         [1.3653224 ],
#         [1.3846742 ],
#         [1.4041523 ],
#         [1.4237547 ],
#         [1.4434798 ],
#         [1.4633262 ],
#         [1.4832921 ],
#         [1.5033758 ],
#         [1.5235759 ],
#         [1.5438901 ],
#         [1.5643173 ],
#         [1.5848557 ],
#         [1.6055036 ],
#         [1.6262591 ],
#         [1.647121  ],
#         [1.6680872 ],
#         [1.6891563 ],
#         [1.7103264 ],
#         [1.7315962 ],
#         [1.7529638 ],
#         [1.7744278 ],
#         [1.795986  ],
#         [1.8176376 ],
#         [1.8393804 ],
#         [1.8612132 ],
#         [1.883134  ],
#         [1.9051414 ],
#         [1.927234  ],
#         [1.9494102 ],
#         [1.9716685 ],
#         [1.9940071 ],
#         [2.016425  ],
#         [2.0389202 ],
#         [2.0614915 ],
#         [2.0841374 ],
#         [2.1068566 ],
#         [2.1296475 ],
#         [2.152509  ],
#         [2.1754394 ],
#         [2.1984372 ],
#         [2.2215016 ],
#         [2.2446308 ],
#         [2.2678235 ],
#         [2.2910788 ],
#         [2.3143952 ],
#         [2.3377714 ],
#         [2.3612063 ],
#         [2.3846984 ],
#         [2.4082468 ],
#         [2.4318502 ],
#         [2.4555073 ],
#         [2.4792173 ],
#         [2.5029788 ],
#         [2.526791  ],
#         [2.5506525 ],
#         [2.574562  ],
#         [2.5985193 ],
#         [2.6225226 ],
#         [2.6465712 ],
#         [2.6706643 ],
#         [2.6948004 ],
#         [2.7189786 ],
#         [2.7431986 ],
#         [2.767459  ],
#         [2.7917588 ],
#         [2.8160973 ],
#         [2.840474  ],
#         [2.8648872 ],
#         [2.8893366 ],
#         [2.9138212 ],
#         [2.9383404 ],
#         [2.9628932 ],
#         [2.9874797 ],
#         [3.0120974 ],
#         [3.0367467 ],
#         [3.0614269 ],
#         [3.0861368 ],
#         [3.1108766 ],
#         [3.1356442 ],
#         [3.1604404 ],
#         [3.1852636 ],
#         [3.2101135 ],
#         [3.2349894 ],
#         [3.259891  ],
#         [3.2848172 ]], dtype=float32)>,
#  '_name': 'sequential_1_distribution_lambda_1_Normal',
#  '_name_scope': <tensorflow.python.framework.ops.name_scope_v2 at 0x7fab8c7b6748>,
#  '_dtype': tf.float32,
#  '_reparameterization_type': <Reparameteriation Type: FULLY_REPARAMETERIZED>,
#  '_allow_nan_stats': True,
#  '_validate_args': False,
#  '_parameters_sanitized': True,
#  '_self_setattr_tracking': True,
#  '_self_unconditional_checkpoint_dependencies': [TrackableReference(name='_graph_parents', ref=ListWrapper([]))],
#  '_self_unconditional_dependency_names': {'_graph_parents': ListWrapper([])},
#  '_self_unconditional_deferred_dependencies': {},
#  '_self_update_uid': -1,
#  '_self_name_based_restores': set(),
#  '_self_saveable_object_factories': {},
#  '_graph_parents': ListWrapper([]),
#  '_defer_all_assertions': False,
#  '_initial_parameter_control_dependencies': (),
#  '_concrete_value': <tf.Tensor: shape=(150, 1), dtype=float32, numpy=
#  array([[ 2.9160423],
#         [ 2.7748287],
#         [ 2.9693422],
#         [ 3.3619175],
#         [ 3.6816065],
#         [ 2.6988049],
#         [ 3.1101987],
#         [ 3.1944559],
#         [ 3.340564 ],
#         [ 3.8172545],
#         [ 3.7847846],
#         [ 2.657054 ],
#         [ 3.931169 ],
#         [ 3.597607 ],
#         [ 3.6567943],
#         [ 3.8728273],
#         [ 4.4826083],
#         [ 4.4667816],
#         [ 3.5539455],
#         [ 3.9278085],
#         [ 3.5551114],
#         [ 5.8263865],
#         [ 4.839107 ],
#         [ 3.9263308],
#         [ 6.0936027],
#         [ 4.974205 ],
#         [ 3.9993818],
#         [ 5.083106 ],
#         [ 4.2782717],
#         [ 5.275552 ],
#         [ 5.2517104],
#         [ 5.4376707],
#         [ 4.2877026],
#         [ 4.245907 ],
#         [ 3.225689 ],
#         [ 5.4678125],
#         [ 6.31801  ],
#         [ 5.886959 ],
#         [ 6.3612866],
#         [ 6.006592 ],
#         [ 4.9822497],
#         [ 5.2806025],
#         [ 4.4494615],
#         [ 7.157688 ],
#         [ 5.140899 ],
#         [ 4.4016047],
#         [ 3.7696352],
#         [ 6.17168  ],
#         [ 7.3661165],
#         [ 5.7544055],
#         [ 6.676858 ],
#         [ 5.832253 ],
#         [ 5.543693 ],
#         [ 7.0742335],
#         [ 5.776715 ],
#         [ 4.870947 ],
#         [ 5.8575544],
#         [ 5.4786844],
#         [ 6.381948 ],
#         [ 6.65439  ],
#         [ 7.5176697],
#         [ 8.729958 ],
#         [ 6.282593 ],
#         [ 6.3503966],
#         [ 6.9902105],
#         [ 2.748332 ],
#         [ 5.425751 ],
#         [ 6.438955 ],
#         [ 8.975107 ],
#         [ 7.4005504],
#         [ 6.663343 ],
#         [ 6.4793663],
#         [ 6.9952736],
#         [ 5.6724467],
#         [ 8.563396 ],
#         [ 7.4530163],
#         [ 7.362115 ],
#         [ 9.7929325],
#         [ 7.1570935],
#         [ 7.452711 ],
#         [ 7.310322 ],
#         [ 8.967873 ],
#         [ 6.2943864],
#         [ 8.328571 ],
#         [ 9.165972 ],
#         [ 5.470732 ],
#         [10.895396 ],
#         [11.253462 ],
#         [ 7.317052 ],
#         [ 8.197687 ],
#         [ 9.389968 ],
#         [ 7.590551 ],
#         [ 6.1337996],
#         [11.089943 ],
#         [ 9.260962 ],
#         [11.726074 ],
#         [ 6.617862 ],
#         [ 9.155402 ],
#         [ 9.014078 ],
#         [ 9.7339115],
#         [10.506408 ],
#         [ 9.916041 ],
#         [ 7.35586  ],
#         [ 6.29395  ],
#         [ 6.421549 ],
#         [ 7.738168 ],
#         [ 6.411322 ],
#         [12.463653 ],
#         [11.488817 ],
#         [ 7.5886307],
#         [ 7.947385 ],
#         [ 8.381841 ],
#         [11.416414 ],
#         [10.547261 ],
#         [10.541159 ],
#         [ 9.749615 ],
#         [11.026819 ],
#         [ 9.896951 ],
#         [10.554478 ],
#         [11.91764  ],
#         [11.3689   ],
#         [11.808423 ],
#         [12.459393 ],
#         [10.198882 ],
#         [14.027937 ],
#         [15.088457 ],
#         [10.19944  ],
#         [14.909905 ],
#         [13.686684 ],
#         [10.517971 ],
#         [ 6.332088 ],
#         [ 9.276712 ],
#         [13.605217 ],
#         [ 7.791646 ],
#         [15.945604 ],
#         [14.140541 ],
#         [15.65959  ],
#         [17.059793 ],
#         [ 6.1182847],
#         [12.414889 ],
#         [10.207196 ],
#         [ 8.906853 ],
#         [11.722864 ],
#         [13.083384 ],
#         [12.419289 ],
#         [14.865656 ],
#         [14.74453  ],
#         [13.966611 ],
#         [19.745224 ],
#         [14.985581 ]], dtype=float32)>,
#  '_convert_to_tensor_fn': <function tensorflow_probability.python.distributions.distribution.Distribution.sample(self, sample_shape=(), seed=None, name='sample', **kwargs)>,
#  '_Distribution__cached_batch_shape': TensorShape([150, 1]),
#  'get_shape': <bound method _EagerTensorBase.get_shape of <tf.Tensor: shape=(150, 1), dtype=float32, numpy=
#  array([[ 2.9160423],
#         [ 2.7748287],
#         [ 2.9693422],
#         [ 3.3619175],
#         [ 3.6816065],
#         [ 2.6988049],
#         [ 3.1101987],
#         [ 3.1944559],
#         [ 3.340564 ],
#         [ 3.8172545],
#         [ 3.7847846],
#         [ 2.657054 ],
#         [ 3.931169 ],
#         [ 3.597607 ],
#         [ 3.6567943],
#         [ 3.8728273],
#         [ 4.4826083],
#         [ 4.4667816],
#         [ 3.5539455],
#         [ 3.9278085],
#         [ 3.5551114],
#         [ 5.8263865],
#         [ 4.839107 ],
#         [ 3.9263308],
#         [ 6.0936027],
#         [ 4.974205 ],
#         [ 3.9993818],
#         [ 5.083106 ],
#         [ 4.2782717],
#         [ 5.275552 ],
#         [ 5.2517104],
#         [ 5.4376707],
#         [ 4.2877026],
#         [ 4.245907 ],
#         [ 3.225689 ],
#         [ 5.4678125],
#         [ 6.31801  ],
#         [ 5.886959 ],
#         [ 6.3612866],
#         [ 6.006592 ],
#         [ 4.9822497],
#         [ 5.2806025],
#         [ 4.4494615],
#         [ 7.157688 ],
#         [ 5.140899 ],
#         [ 4.4016047],
#         [ 3.7696352],
#         [ 6.17168  ],
#         [ 7.3661165],
#         [ 5.7544055],
#         [ 6.676858 ],
#         [ 5.832253 ],
#         [ 5.543693 ],
#         [ 7.0742335],
#         [ 5.776715 ],
#         [ 4.870947 ],
#         [ 5.8575544],
#         [ 5.4786844],
#         [ 6.381948 ],
#         [ 6.65439  ],
#         [ 7.5176697],
#         [ 8.729958 ],
#         [ 6.282593 ],
#         [ 6.3503966],
#         [ 6.9902105],
#         [ 2.748332 ],
#         [ 5.425751 ],
#         [ 6.438955 ],
#         [ 8.975107 ],
#         [ 7.4005504],
#         [ 6.663343 ],
#         [ 6.4793663],
#         [ 6.9952736],
#         [ 5.6724467],
#         [ 8.563396 ],
#         [ 7.4530163],
#         [ 7.362115 ],
#         [ 9.7929325],
#         [ 7.1570935],
#         [ 7.452711 ],
#         [ 7.310322 ],
#         [ 8.967873 ],
#         [ 6.2943864],
#         [ 8.328571 ],
#         [ 9.165972 ],
#         [ 5.470732 ],
#         [10.895396 ],
#         [11.253462 ],
#         [ 7.317052 ],
#         [ 8.197687 ],
#         [ 9.389968 ],
#         [ 7.590551 ],
#         [ 6.1337996],
#         [11.089943 ],
#         [ 9.260962 ],
#         [11.726074 ],
#         [ 6.617862 ],
#         [ 9.155402 ],
#         [ 9.014078 ],
#         [ 9.7339115],
#         [10.506408 ],
#         [ 9.916041 ],
#         [ 7.35586  ],
#         [ 6.29395  ],
#         [ 6.421549 ],
#         [ 7.738168 ],
#         [ 6.411322 ],
#         [12.463653 ],
#         [11.488817 ],
#         [ 7.5886307],
#         [ 7.947385 ],
#         [ 8.381841 ],
#         [11.416414 ],
#         [10.547261 ],
#         [10.541159 ],
#         [ 9.749615 ],
#         [11.026819 ],
#         [ 9.896951 ],
#         [10.554478 ],
#         [11.91764  ],
#         [11.3689   ],
#         [11.808423 ],
#         [12.459393 ],
#         [10.198882 ],
#         [14.027937 ],
#         [15.088457 ],
#         [10.19944  ],
#         [14.909905 ],
#         [13.686684 ],
#         [10.517971 ],
#         [ 6.332088 ],
#         [ 9.276712 ],
#         [13.605217 ],
#         [ 7.791646 ],
#         [15.945604 ],
#         [14.140541 ],
#         [15.65959  ],
#         [17.059793 ],
#         [ 6.1182847],
#         [12.414889 ],
#         [10.207196 ],
#         [ 8.906853 ],
#         [11.722864 ],
#         [13.083384 ],
#         [12.419289 ],
#         [14.865656 ],
#         [14.74453  ],
#         [13.966611 ],
#         [19.745224 ],
#         [14.985581 ]], dtype=float32)>>}

# %% [markdown]
# ## Try with Ezsmdeploy

# %%
# %%writefile tfp_predict_script.py
import tensorflow as tf
import tensorflow_probability as tfp
import numpy as np
import json
import h5py
import os
tfd = tfp.distributions

#Return loaded model
def load_model(modelpath):

    # (re)Defne model
    negloglik = lambda y, rv_y: -rv_y.log_prob(y)
    model = tf.keras.Sequential([
      tf.keras.layers.Dense(1 + 1),
      tfp.layers.DistributionLambda(
          lambda t: tfd.Normal(loc=t[..., :1],
                               scale=1e-3 + tf.math.softplus(0.05 * t[...,1:]))),
    ])


    # Load model
    print("1. Listing files in modelpath")
    print(os.listdir(modelpath))
    
    print("2. Loading h5 file")
    file = h5py.File(os.path.join(modelpath,'reg1.h5'), 'r')
    
    print("3. Loading weights")
    weight = []
    for i in range(len(file.keys())):
       weight.append(file['weight' + str(i)][:])

    model.build(input_shape = (150,1))
    model.set_weights(weight)
    
    print("4. Loaded model successfully")
    
    return model

# return prediction based on loaded model (from the step above) and an input payload
def predict(model, payload):
    try:
        # Note, for Multi model endpoints -> (payload[0]['body'].decode())
        data = np.frombuffer(payload,dtype=np.float32).reshape((150,1))
        tmpout = model(data)
        
        #Add outputs here !!
        
        out = {
            'mean':np.asarray(tmpout.mean()).T.tolist(),
            'mode':np.asarray(tmpout.mode()).T.tolist(),
            'stddev':np.asarray(tmpout.stddev()).T.tolist(),
            'quantile_75':np.asarray(tmpout.quantile(0.75)).T.tolist()
            }
                                     
    except Exception as e:
        out = str(e)
    return [json.dumps({'output':out})]
# Out:
# Overwriting tfp_predict_script.py

# %% [markdown]
# ## Does this work Locally in the notebook?

# %%
from tfp_predict_script import *
.981863021850586, 12.047807693481445, 12.113754272460938, 12.179699897766113, 12.245645523071289, 12.311591148376465, 12.37753677368164, 12.443483352661133, 12.509428024291992, 12.575374603271484]], "mode": [[2.7494661808013916, 2.8154118061065674, 2.881357431411743, 2.947303295135498, 3.013248920440674, 3.0791947841644287, 3.1451401710510254, 3.211085796356201, 3.277031660079956, 3.342977285385132, 3.4089231491088867, 3.4748687744140625, 3.5408143997192383, 3.606760025024414, 3.672705888748169, 3.7386512756347656, 3.8045971393585205, 3.8705430030822754, 3.936488628387451, 4.002434253692627, 4.068379878997803, 4.1343255043029785, 4.200271129608154, 4.266217231750488, 4.332162857055664, 4.39810848236084, 4.464054107666016, 4.529999732971191, 4.595945358276367, 4.661890983581543, 4.727836608886719, 4.793782711029053, 4.8597283363342285, 4.925673961639404, 4.99161958694458, 5.057565212249756, 5.123510837554932, 5.189456462860107, 5.255402565002441, 5.321348190307617, 5.387293815612793, 5.453239440917969, 5.5191850662231445, 5.58513069152832, 5.651076316833496, 5.717021942138672, 5.782968044281006, 5.848913669586182, 5.914859294891357, 5.980804920196533, 6.046750545501709, 6.112696170806885, 6.178642272949219, 6.2445878982543945, 6.31053352355957, 6.376479148864746,  ...

# %% [markdown]
# ## Deploy locally in a container

# %%
import ezsmdeploy

# %% [markdown]
# Match versions used in your notebook to make sure the endpoint deploys correctly!

# %%
# !pip show numpy tensorflow tensorflow-probability  h5py

# %%
ez = ezsmdeploy.Deploy(model = 'reg1.h5', 
                  script = 'tfp_predict_script.py',
                  requirements = ['numpy','tensorflow>=2.5','tensorflow-probability','h5py'], #or pass in the path to requirements.txt
                  instance_type = 'local',
                  wait = True)
# Out:
# 0:00:00.003602 | compressed model(s)
# 0:00:00.075285 | uploaded model tarball(s) ; check returned modelpath
# 0:00:00.076126 | added requirements file
# 0:00:00.077954 | added source file
# 0:00:00.079299 | added Dockerfile
# 0:00:00.081173 | added model_handler and docker utils
# 0:00:00.081804 | building docker container
# 0:01:31.233938 | built docker container
# update_endpoint is a no-op in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# 0:01:31.349462 | created model(s). Now deploying on local
# ∙●∙ Attaching to tmp6serw1sh_algo-1-g8yvq_1
# algo-1-g8yvq_1  | Starting the inference server with 16 workers.
# ∙∙∙ algo-1-g8yvq_1  | [2021-09-01 03:39:13 +0000] [9] [INFO] Starting gunicorn 20.1.0
# algo-1-g8yvq_1  | [2021-09-01 03:39:13 +0000] [9] [INFO] Listening at: unix:/tmp/gunicorn.sock (9)
# algo-1-g8yvq_1  | [2021-09-01 03:39:13 +0000] [9] [INFO] Using worker: gevent
# algo-1-g8yvq_1  | [2021-09-01 03:39:13 +0000] [13] [INFO] Booting worker with pid: 13
# algo-1-g8yvq_1  | [2021-09-01 03:39:13 +0000] [14] [INFO] Booting worker with pid: 14
# ∙∙∙ algo-1-g8yvq_1  | [2021-09-01 03:39:13 +0000] [15] [INFO] Booting worker with pid: 15
# algo-1-g8yvq_1  | [2021-09-01 03:39:13 +0000] [16] [INFO] Booting worker with pid: 16
132, 3.4089231491088867, 3.4748687744140625, 3.5408143997192383, 3.606760025024414, 3.672705888748169, 3.7386512756347656, 3.8045971393585205, 3.8705430030822754, 3.936488628387451, 4.002434253692627, 4.068379878997803, 4.1343255043029785, 4.200271129608154, 4.266217231750488, 4.332162857055664, 4.39810848236084, 4.464054107666016, 4.529999732971191, 4.595945358276367, 4.661890983581543, 4.727836608886719, 4.793782711029053, 4.8597283363342285, 4.925673961639404, 4.99161958694458, 5.057565212249756, 5.123510837554932, 5.189456462860107, 5.255402565002441, 5.321348190307617, 5.387293815612793, 5.453239440917969, 5.5191850662231445, 5.58513069152832, 5.651076316833496, 5.717021942138672, 5.782968044281006, 5.848913669586182, 5.914859294891357, 5.980804920196533, 6.046750545501709, 6.112696170806885, 6.178642272949219, 6.2445878982543945, 6.31053352355957, 6.376479148864746, 6 ...
# algo-1-g8yvq_1  | 172.20.0.1 - - [01/Sep/2021:03:39:19 +0000] "POST /invocations HTTP/1.1" 200 11698 "-" "python-urllib3/1.26.4"

# %% [markdown]
# ## Great! Now deploy onto a SageMaker endpoint

# %%
ezonsm = ezsmdeploy.Deploy(model = 'reg1.h5', 
                  script = 'tfp_predict_script.py',
                  requirements = ['numpy','tensorflow>=2.5','tensorflow-probability','h5py'], #or pass in the path to requirements.txt
                  instance_type = 'ml.m4.xlarge', #... or let ezsmdeploy decide instance type based on model size
                  wait = True)
# Out:
# 0:00:00.003749 | compressed model(s)
# 0:00:00.158802 | uploaded model tarball(s) ; check returned modelpath
# 0:00:00.159965 | added requirements file
# 0:00:00.162085 | added source file
# 0:00:00.164027 | added Dockerfile
# 0:00:00.165969 | added model_handler and docker utils
# 0:00:00.166121 | building docker container
# 0:01:34.311422 | built docker container
# 2m∙∙∙
# update_endpoint is a no-op in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# 0:01:34.436429 | created model(s). Now deploying on ml.m4.xlarge
# 0:05:37.171200 | deployed model
# 0:05:37.172185 | estimated cost is $0.31 per hour
# 0:05:37.172339 | Done! ✔

# %%
out = ezonsm.predictor.predict(x_tst.tobytes()).decode()
out
# Out:
# '{"output": {"mean": [[2.7494661808013916, 2.8154118061065674, 2.881357431411743, 2.947303295135498, 3.013248920440674, 3.0791947841644287, 3.1451401710510254, 3.211085796356201, 3.277031660079956, 3.342977285385132, 3.4089231491088867, 3.4748687744140625, 3.5408143997192383, 3.606760025024414, 3.672705888748169, 3.7386512756347656, 3.8045971393585205, 3.8705430030822754, 3.936488628387451, 4.002434253692627, 4.068379878997803, 4.1343255043029785, 4.200271129608154, 4.266217231750488, 4.332162857055664, 4.39810848236084, 4.464054107666016, 4.529999732971191, 4.595945358276367, 4.661890983581543, 4.727836608886719, 4.793782711029053, 4.8597283363342285, 4.925673961639404, 4.99161958694458, 5.057565212249756, 5.123510837554932, 5.189456462860107, 5.255402565002441, 5.321348190307617, 5.387293815612793, 5.453239440917969, 5.5191850662231445, 5.58513069152832, 5.651076316833496, 5.717021942138672, 5.782968044281006, 5.848913669586182, 5.914859294891357, 5.980804920196533, 6.046750545501709, 